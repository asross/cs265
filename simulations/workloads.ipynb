# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
from figure_grid import *
from workloads import *

# %%
wlks = [RoundRobinWorkload, ZipfWorkload, MultinomialWorkload, TimeDecayBetaMultWorkload]

# %%
wls = [wlk().generate() for wlk in wlks]

# %%
with figure_grid(2,2, rowheight=4) as g:
  for i in range(len(wls)):
    g.next()
    
    plt.title(wlks[i].__name__)
    plt.xlim(0, 25000)
    if wlks[i].__name__ == 'ZipfWorkload':
      plt.yscale('log')
    else:
      plt.ylim(0, max(wls[i]))
    plt.scatter(range(len(wls[i])), wls[i], alpha=0.025)
